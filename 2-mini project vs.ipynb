# %%
import pandas as pd       #Sales
df=pd.read_csv("C:\\Users\\megal\\Downloads\\Sales.csv")
df
print(df.columns)
df.drop_duplicates(inplace=True)
df
df.isnull().sum()
df.drop("Delivery Date",axis=1)
df["Delivery Date"].fillna(df["Delivery Date"].mode()[0],inplace=True)
df.isnull().sum()
df["Delivery Date"].mode()
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()        
df["Currency Code"] = l.fit_transform(df["Currency Code"])
df["Order Date"]=l.fit_transform(df["Order Date"])
df["Delivery Date"]=l.fit_transform(df["Delivery Date"])
df
# Out:
# Index(['Unnamed: 0', 'Order Number', 'Line Item', 'Order Date',
#        'Delivery Date', 'CustomerKey', 'StoreKey', 'ProductKey', 'Quantity',
#        'Currency Code'],
#       dtype='object')
# C:\Users\megal\AppData\Local\Temp\ipykernel_24520\2726605786.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Delivery Date"].fillna(df["Delivery Date"].mode()[0],inplace=True)
#        Unnamed: 0  Order Number  Line Item  Order Date  Delivery Date  \
# ...

# %%
df.to_csv('C:\\Users\\megal\\Downloads\\sales.csv')

# %%
import pandas as pd
df1 = pd.read_csv("C:\\Users\\megal\\Downloads\\Stores.csv")   #Stores
df1
df1.isnull().sum()
df1= df1.fillna("Square Meters"=="ffill")
df1
df1.isnull().sum()
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder() 
df1["Country"]=l.fit_transform(df1["Country"])
df1["State"]=l.fit_transform(df1["State"])
df1["Square Meters"]=l.fit_transform(df1["Square Meters"])
df1["Open Date"]=l.fit_transform(df1["Open Date"])
df1
# Out:
#     StoreKey  Country  State  Square Meters  Open Date
# 0          1        0      3              7          0
# 1          2        0     46              8          5
# 2          3        0     55             34          6
# 3          4        0     58             34          1
# 4          5        0     60             34          9
# ..       ...      ...    ...            ...        ...
# 62        63        8     59             34         12
# 63        64        8     61             23          1
# 64        65        8     62             30          2
# 65        66        8     64              9          3
# 66         0        6     49              0          1
#
# [67 rows x 5 columns]

# %%
df1.to_csv('C:\\Users\\megal\\Downloads\\store.csv')

# %%
df2=pd.read_csv("C:\\Users\\megal\\Downloads\\Products.csv")    #Products
df2
df2.isnull().sum()
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df2["Product Name"]=l.fit_transform(df2["Product Name"])
df2["Brand"]=l.fit_transform(df2["Brand"])
df2["Color"]=l.fit_transform(df2["Color"])
df2["Subcategory"]=l.fit_transform(df2["Subcategory"])
df2["Category"]=l.fit_transform(df2["Category"])
df2["Unit Cost USD"]=l.fit_transform(df2["Unit Cost USD"])
df2["Unit Price USD"]=l.fit_transform(df2["Unit Price USD"])
df2
# Out:
#       ProductKey  Product Name  Brand  Color  Unit Cost USD  Unit Price USD  \
# 0              1           376      2     11            377              42
# 1              2           375      2      2            377              42
# 2              3           337      2     14            396              60
# 3              4           347      2     11             23             123
# 4              5           346      2     10             23             123
# ...          ...           ...    ...    ...            ...             ...
# 2512        2513           443      2     10            320              49
# 2513        2514           444      2     14            320              49
# 2514        2515           676      2     14              4             195
# 2515        2516           674      2      1              4             195
# 2516        2517           675      2     11              4             195
#
#       SubcategoryKey  Subcategory  CategoryKey  Category
# ...

# %%
df2.to_csv('C:\\Users\\megal\\Downloads\\product.csv')

# %%
df3=pd.read_csv("C:\\Users\\megal\\Downloads\\Exchange_Rates.csv")   #Exchange
df3
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
df3["Currency"] = l.fit_transform(df3["Currency"])
df3
df3.isnull().sum()
df3["Exchange"]=l.fit_transform(df3["Exchange"])
df3["Date"]=l.fit_transform(df3["Date"])
df3
# Out:
#        Date  Currency  Exchange
# 0         0         4      1781
# 1         0         1      1782
# 2         0         0      1830
# 3         0         2       994
# 4         0         3        32
# ...     ...       ...       ...
# 11210   859         4      1781
# 11211   859         1      2000
# 11212   859         0      2073
# 11213   859         2       995
# 11214   859         3       312
#
# [11215 rows x 3 columns]

# %%
df3.to_csv('C:\\Users\\megal\\Downloads\\exchange.csv')

# %%
import pandas as pd

df4 = pd.read_csv("C:\\Users\\megal\\Downloads\\Customers.csv", encoding='latin1')    #Customers
df4

df4.columns
from sklearn.preprocessing import LabelEncoder
l = LabelEncoder()
df4["City"] = l.fit_transform(df4["City"])
df4["Gender"] = l.fit_transform(df4["Gender"])
df4["Name"] = l.fit_transform(df4["Name"])
df4["State Code"] = l.fit_transform(df4["State Code"])
df4["State"] = l.fit_transform(df4["State"])
df4["Country"] = l.fit_transform(df4["Country"])
df4["Continent"] = l.fit_transform(df4["Continent"])
df4
df4["State Code"].fillna(df4["State Code"].mode()[0],inplace=True)
df4["Birthday"]=l.fit_transform(df4["Birthday"])
df4
# Out:
# C:\Users\megal\AppData\Local\Temp\ipykernel_7068\306343131.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df4["State Code"].fillna(df4["State Code"].mode()[0],inplace=True)
#        CustomerKey  Gender   Name  City  State Code  State Zip Code  Country  \
# 0              301       0   8756  7709         336    395     5523        0
# 1              325       0   9320  4632         426    490     6522        0
# 2              554       0   2672  7832         420    465     3380        0
# ...

# %%
df4.to_csv('C:\\Users\\megal\\Downloads\\customer.csv')

# %%
df4['age'] = (pd.to_datetime('today') - pd.to_datetime(df4['Birthday'])).dt.days // 365
df4['age']
# Out:
# 0        85
# 1        45
# 2        77
# 3        67
# 4        59
#          ..
# 15261    88
# 15262    32
# 15263    87
# 15264    87
# 15265    59
# Name: age, Length: 15266, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x='Gender', data=df4)
plt.title('Gender Distribution')
plt.show()

sns.histplot(df4['age'], bins=45)
plt.title('Age Distribution')
plt.show()

plt.figure(figsize=(12, 6))
sns.countplot(x='Country', data=df4)
plt.title('Country Distribution')
plt.xticks(rotation=45)
plt.show()

# %%
avg_order_value = df.groupby('Order Number')['CustomerKey'].mean().mean()
print('Average Order Value:', avg_order_value)

purchase_frequency = df.groupby('CustomerKey')['Order Date'].count().mean()
print('Average Purchase Frequency:', purchase_frequency)
# Out:
# Average Order Value: 1183849.4437058421
# Average Purchase Frequency: 5.290148902162025

# %%
top_products = df2['CategoryKey'].value_counts().head(10)
sns.barplot(x=top_products.index, y=top_products.values)
plt.title('Top 10 Product Categories')
plt.xticks(rotation=45)
plt.show()

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

import matplotlib.pyplot as plt
top_products = df.groupby('ProductKey')['Quantity'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_products.index, y=top_products.values)
plt.xlabel('Product')
# Out:
# Text(0.5, 0, 'Product')

# %%
plt.ylabel('Quantity Sold')
plt.title('Top 10 Products by Quantity')
plt.xticks(rotation=45)
plt.show()

# %%
top_stores = df.groupby('StoreKey')['ProductKey'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_stores.index, y=top_stores.values)
plt.xlabel('Store')
plt.ylabel('Currency Code')
plt.title('Top 10 Stores by Sales')
plt.xticks(rotation=45)
plt.show()

# %%
#Product Popularity
#Most Popular Products by Quantity Sold
top_products_quantity = df.groupby('ProductKey')['Quantity'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))   
sns.barplot(x=top_products_quantity.index, y=top_products_quantity.values)
plt.xlabel('Product')
plt.ylabel('Quantity Sold')
plt.title('Top 10 Products by Quantity Sold')
plt.xticks(rotation=45)
plt.show()


#Least Popular Products by Quantity Sold
bottom_products_quantity = df.groupby('ProductKey')['Quantity'].sum().sort_values(ascending=True).head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=bottom_products_quantity.index, y=bottom_products_quantity.values)
plt.xlabel('Product')
plt.ylabel('Quantity Sold')
plt.title('Bottom 10 Products by Quantity Sold')
plt.xticks(rotation=45)
plt.show()

# %%
#Category Analysis

category_sales = df2.groupby('Category')['Unit Price USD'].sum()
plt.figure(figsize=(50, 50))
sns.barplot(x=category_sales.index, y=category_sales.values)
plt.xlabel('Category')
plt.ylabel('Unit Price USD')
plt.title('Unit Price USD by Category')
plt.xticks(rotation=45)
plt.show()

# Subcategory Analysis

subcategory_sales = df2.groupby('Subcategory')['Unit Price USD'].sum()
plt.figure(figsize=(12, 6))
sns.barplot(x=subcategory_sales.index, y=subcategory_sales.values)
plt.xlabel('Subcategory')
plt.ylabel('Unit Price USD ')
plt.title('Unit Price USD by Subcategory')
plt.xticks(rotation=45)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 #Category Analysis
# ----> 3 category_sales = df2.groupby('Category')['Unit Price USD'].sum()
#       4 plt.figure(figsize=(50, 50))
#       5 sns.barplot(x=category_sales.index, y=category_sales.values)
#
# NameError: name 'df2' is not defined

# %%
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import pymysql
#sales
def  mysqlconnect():
  Mydb = pymysql.connect(
     host="localhost",
     user="root",
     password="Sanjana@2003",
     database="dataspark"
   )

  mycursor = Mydb.cursor()

  create_table_query = """
  CREATE TABLE sales(
    Order Number int Primary key,
    Line Item int,
    Order Date DATE,
    Delivery Date DATE,
    CustomerKey int,
    StoreKey int,
    ProductKey int,
    Quantity int,
    Currency Code int
    )
    """
 

  mycursor.close()
 

mysqlconnect()
print("Table 'sales' created successully!")
# Out:
# Table 'sales' created successully!

# %%
ins_que='''INSERT INTO sales(
                 Order Number int Primary key,
                 Line Item int,
                 Order Date DATE,
                 Delivery Date DATE,
                 CustomerKey int,
                 StoreKey int,'
                 ProductKey int,
                 Quantity int,
                 Currency Code int )
                 VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s)
                  '''
data = df.values.tolist()
print("Success")
# Out:
# Success

# %%
#Stores
create_table_query = """
  CREATE TABLE Stores(
    StoreKey int,
    Country int,
    State int,
    Square Meters int,
    Open Date
    )
    """
print("Table 'Stores' created successully!")
# Out:
# Table 'Stores' created successully!

# %%
ins_que = '''INSERT INTO Stores(
    StoreKey int,
    Country int,
    State int,
    Square Meters int,
    Open Date)
    VALUES(%s,%s,%s,%s,%s)
    '''
data = df1.values.tolist()
print("success")
# Out:
# success

# %%
#Products
create_table_query = '''create table Products(
                        ProductKey int,
                        Product Name int,
                        Brand int,
                        Color int,
                        Unit Cost USD,
                        Unit Price USD,
                        SubcategoryKey,
                        Subcategory,
                        CategoryKey,
                        Category
                        )'''
print("product")
# Out:
# product

# %%
ins_que='''INSERT INTO Products(
                        ProductKey int,
                        Product Name int,
                        Brand int,
                        Color int,
                        Unit Cost USD,
                        Unit Price USD,
                        SubcategoryKey,
                        Subcategory,
                        CategoryKey,
                        Category)
                        VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
                        '''
data = df2.values.tolist()
print("my success")
# Out:
# my success

# %%
#Exchange

create_table_query = ('''CREATE TABLE Exchange(
                  Date DATE,
                  Currency int,
                  Exchange float)
                  ''')
  


print("execute")
# Out:
# execute

# %%
ins_que = '''INSERT INTO execute(Date DATE,
                  Currency int,
                  Exchange float)
                  VALUES(%s,%s,%s)
                  '''
data = df3.values.tolist()
print("insert")
# Out:
# insert

# %%
import pymysql
#Customer
def  mysqlconnect():
  Mydb = pymysql.connect(
     host="localhost",
     user="root",
     password="Sanjana@2003",
     database="dataspark"
   )

  mycursor = Mydb.cursor()
  my_cursor.execute('''CREATE TABLE if not exists Customer(
                  CustomerKey int,
                  Gender int,
                  Name int,
                  City int,
                  State Code int,
                  State int,
                  Zip Code int,
                  Country int,
                  Continent int,
                  Birthday DATE)
                  ''')



  mycursor.close()
  mydb.close()
print("Success")
# Out:
# Success

# %%
import pymysql

def  mysqlconnect():
  Mydb = pymysql.connect(
     host="localhost",
     user="root",
     password="Sanjana@2003",
     database="dataspark"
   )

  mycursor = Mydb.cursor()
  ins_que = '''INSERT INTO Customer(
                  CustomerKey int,
                  Gender int,
                  Name int,
                  City int,
                  State Code int,
                  State int,
                  Zip Code int,
                  Country int,
                  Continent int,
                  Birthday DATE)
                  VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
  data = df4.values.tolist()
  my_cursor.executemany(ins_que,data)
  mycursor.close()
  mydb.close()
print("insert")
# Out:
# insert
